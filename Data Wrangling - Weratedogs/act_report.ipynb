# %% [markdown]
# ## Introduction
#
# After wrangling our data, we step into Analyzing, and Visualizing Data for this project. Here we come across various insights from our data which cannot be inferred by visual assessments of our data.
#
# **For actual code for the plots please look up wrangle_act.ipynb in the same directory**

# %% [markdown]
# ## Analyzing, and Visualizing Data

# %%
plt.show()

# %% [markdown]
# In my first plot, i first made a log transformation of my master data on certain variables that could show potential relationships. Then i plotted a scatter matrix of the same.
#
# I made the following observations.
# - There seems to be a **strong correlation between favorite_count and retweet_count**.
# - Most of the plots dont seem to show any correlation between each other.
# - Was able to visualize that retweet count is able to follow a normal distribution with a slight left skewness.
#
# I proceeded to plot a correlation heatmap for the same.

# %%
plt.show()
# Out:
# Text(0.5,1,'Correlation Map')

# %% [markdown]
# The following observations were made after plotting the correlation map.
# - The insights that we predicted from our previous plot seems to be true.
# - We see that there is a minimal correlation of 0.2 between retweet_count VS rating_percent and between favorite_count VS rating_percent. It is evident that both favorite_count and retweet_count are both slightly related with rating_percent since they are highly correlated by themselves.

# %%
pd.DataFrame(twitter_archive_master.dog_stage.value_counts()/twitter_archive_master.dog_stage.value_counts().sum() * 100).rename(columns = {'dog_stage':'Ratio of Dogs in %'}).sort_index()
# Out:
#          Ratio of Dogs in %
# doggo             25.000000
# floofer            2.586207
# pupper            65.517241
# puppo              6.896552

# %% [markdown]
# Here we are able to see that most dogs were puppies (pupper) followed by normally grown dogs (doggo).
# - This might be the case since many people obviously crazy about puppies and would want to share their pics to weratedogs.

# %%
plt.show()

# %% [markdown]
# Here we have plotted the average ratings gained for each dog stages in our dataset.
# - We are able to dog stage puppo takes the lead but by a very slight margin.
# - This is followed by floofer and doggo, but we cannot be sure about dog stage doggo since the number of doggo's are less in our dataset.
# - Overall we see that all are very close and not by a huge margin.

# %%
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# **Rating percentage = rating numerator / rating denominator**<br>
#
# The above plot is a box plot which gives the rating percentage/average rating score in each month throughout the timeline on which the data was collected. (**Average Rating VS Calendar Month**)
#
# - We are able to see that there is a gradual upward movement in the mean rating score through each month.
# - We are able to also see that in the initial months weratedogs were not using a rating system where rating numerator was more than rating denominator.

# %%
plt.show()

# %% [markdown]
# As mentioned in the previous boxplot, the same was plotted over a line chart.  **We can infer the same from the above plotted line chart that average rating scores were increased throughout the years.**

# %%
plt.show()

# %% [markdown]
# I made a plot of the number of tweets/ratings on the channel for each calendar month and was able to find an interesting observation on the whole.
#
# - From previous plots we are able to see that the channel @weratedogs have improved their rating systems and there is upward movement in  average ratings given by the channel throughout the years, but on the contrary we are seeing that the number of rating tweets have shown a negative decline.
# - We might assume that there would have been a high popularity during the initial months given in our dataset and following that it might have decreased but we cannot be sure since there might be other factors also involved such as the admin of the channel was busy with other things and did not have time for @weratedogs.
# - We would need additional data for these insights to be proved. On gathering them we can even tell if changing the rating system has somehow affected its popularity. These are things that as a datascientist we should ponder on.

# %%
plt.show()

# %% [markdown]
# The final plot was made on the gender segregation of the dogs.
# - Here we can see that most of the dogs around 75% are Male while other as Females..
# - We can make a less probable inference that maybe there more male dogs than females in this world..this is another question that we can ponder on from our insights in this data.

# %% [markdown]
# ## Conclusion
#
# From our plots and analyses we were able to find many insights from our data and also we questioned on many more insights that we can look up on but we should always remember that this is all possible due to our wrangling efforts.
